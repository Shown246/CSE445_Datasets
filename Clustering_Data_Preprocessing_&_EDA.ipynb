# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Shown246/CSE445_Datasets/refs/heads/main/Big_Five_Personality_Clustering.csv')
df.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  OPN2  \
# 0   3.0   2.0   3.0   3.0   3.0   4.0   2.0   2.0   1.0    2.0  ...   5.0
# 1   2.0   5.0   2.0   4.0   4.0   5.0   2.0   3.0   1.0    3.0  ...   5.0
# 2   3.0   4.0   4.0   5.0   4.0   5.0   2.0   4.0   3.0    3.0  ...   6.0
# 3   4.0   4.0   4.0   4.0   3.0   4.0   5.0   4.0   4.0    4.0  ...   5.0
# 4   3.0   4.0   2.0   4.0   3.0   5.0   4.0   4.0   3.0    2.0  ...   6.0
#
#    OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10  country
# 0   4.0   5.0   3.0   6.0   4.0   2.0   5.0    3.0       MY
# 1   5.0   5.0   3.0   6.0   4.0   4.0   3.0    3.0       GB
# 2   5.0   6.0   3.0   6.0   5.0   4.0   5.0    2.0       SE
# 3   4.0   4.0   4.0   6.0   5.0   5.0   4.0    4.0       US
# 4   5.0   6.0   5.0   6.0   5.0   5.0   5.0    5.0       UA
#
# [5 rows x 51 columns]

# %%
df.isnull().sum()
# Out:
# EXT1       0
# EXT2       0
# EXT3       0
# EXT4       0
# EXT5       0
# EXT6       0
# EXT7       0
# EXT8       0
# EXT9       0
# EXT10      0
# EST1       0
# EST2       0
# EST3       0
# EST4       0
# EST5       0
# EST6       0
# EST7       0
# EST8       0
# EST9       0
# EST10      0
# AGR1       0
# AGR2       0
# AGR3       0
# AGR4       0
# AGR5       0
# AGR6       0
# AGR7       0
# AGR8       0
# AGR9       0
# AGR10      0
# CSN1       0
# CSN2       0
# CSN3       0
# CSN4       0
# CSN5       0
# CSN6       0
# CSN7       0
# CSN8       0
# CSN9       0
# CSN10      0
# OPN1       0
# OPN2       0
# OPN3       0
# OPN4       0
# OPN5       0
# OPN6       0
# OPN7       0
# OPN8       0
# OPN9       0
# OPN10      0
# country    0
# dtype: int64

# %%
df = df.drop(columns=['country'])
df.describe()
# Out:
#                 EXT1           EXT2           EXT3           EXT4  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        2.576208       4.151966       3.231092       3.780756
# std         1.237665       1.306216       1.192146       1.205431
# min         1.000000       2.000000       1.000000       2.000000
# 25%         1.000000       3.000000       2.000000       3.000000
# 50%         3.000000       4.000000       3.000000       4.000000
# 75%         3.000000       5.000000       4.000000       5.000000
# max         5.000000       6.000000       5.000000       6.000000
#
#                 EXT5           EXT6           EXT7           EXT8  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        3.249236       4.576850       2.711672       3.530542
# std         1.247157       1.214254       1.370166       1.239375
# min         1.000000       2.000000       1.000000       2.000000
# 25%         2.000000       4.000000       1.000000       2.000000
# 50%         3.000000       5.000000       3.000000       3.000000
# 75%         4.000000       6.000000       4.000000       4.000000
# max         5.000000       6.000000       5.000000       6.000000
#
#                 EXT9          EXT10  ...           OPN1           OPN2  \
# count  500000.000000  500000.000000  ...  500000.000000  500000.000000
# mean        2.953574       3.377892  ...       3.777858       4.978200
# std         1.325302       1.263613  ...       1.075084       1.083734
# min         1.000000       2.000000  ...       1.000000       2.000000
# 25%         2.000000       2.000000  ...       3.000000       4.000000
# 50%         3.000000       3.000000  ...       4.000000       5.000000
# 75%         4.000000       4.000000  ...       5.000000       6.000000
# max         5.000000       6.000000  ...       5.000000       6.000000
#
#                 OPN3           OPN4           OPN5           OPN6  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        4.066512       5.048276       3.833172       5.121922
# std         1.027651       1.059575       0.930685       1.073005
# min         1.000000       2.000000       1.000000       2.000000
# 25%         3.000000       4.000000       3.000000       5.000000
# 50%         4.000000       5.000000       4.000000       5.000000
# 75%         5.000000       6.000000       5.000000       6.000000
# max         5.000000       6.000000       5.000000       6.000000
#
#                 OPN7           OPN8           OPN9          OPN10
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        4.059544       3.283770       4.221108       3.996386
# std         0.918797       1.212914       0.939106       0.983751
# min         1.000000       1.000000       1.000000       1.000000
# 25%         4.000000       2.000000       4.000000       3.000000
# 50%         4.000000       3.000000       4.000000       4.000000
# 75%         5.000000       4.000000       5.000000       5.000000
# max         5.000000       5.000000       5.000000       5.000000
#
# [8 rows x 50 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
numerical_cols = df.select_dtypes(include=['number']).columns

# Create boxplots for numerical columns
plt.figure(figsize=(20, 8))
sns.boxplot(data=df[numerical_cols])
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary
plt.title("Boxplot of Numerical Columns")
plt.show()

# %%
from scipy import stats
# Outlier detection using Z-score method
z_scores = stats.zscore(df[numerical_cols])
abs_z_scores = abs(z_scores)
threshold = 3
outlier_indices = (abs_z_scores > threshold).any(axis=1)

# Number of outliers detected
print("Number of outliers detected:", outlier_indices.sum())
# Out:
# Number of outliers detected: 30663

# %%
# Outlier detection using IQR method
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

outliers_mask = (df[numerical_cols] < (Q1 - 1.5 * IQR)) | (df[numerical_cols] > (Q3 + 1.5 * IQR))
outliers_df = df[outliers_mask.any(axis=1)]

# Print IQR results
print("Outliers detected using IQR:", outliers_df.shape[0])
# print(outliers_mask.sum())  # Total number of outliers column-wise
# Out:
# Outliers detected using IQR: 156471

# %% [markdown]
# ### We won't remove the outliers
